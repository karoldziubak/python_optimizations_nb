# %% [markdown]
# # Loops in Python
# As shown in `basics.ipynb` we can speed up the execution time of a loop by using list comprehension or generator expression. Here we will look at a few other ways to speed up the execution time of a loop or even eliminate the need for a loop entirely.
#
# - Counter
# - itertools

# %% [markdown]
# ## Counting occurrences in loop vs collections.Counter

# %%
from itertools import combinations
from collections import Counter
import numpy as np
np.random.seed(1)

# %% [markdown]
# Prepare some example data:

# %%
zodiacs = ('Aries', 'Taurus', 'Gemini', 'Cancer', 'Leo', 'Virgo', 'Libra', 'Scorpio', 'Sagittarius', 'Capricorn', 'Aquarius', 'Pisces')
zodiac_weights = np.random.random(12)
zodiac_probabilities = zodiac_weights / zodiac_weights.sum()

data_big = np.random.choice(zodiacs, p=zodiac_probabilities, size=1000).tolist()

data_big
# Out:
# ['Taurus',
#  'Pisces',
#  'Aries',
#  'Capricorn',
#  'Libra',
#  'Sagittarius',
#  'Taurus',
#  'Taurus',
#  'Aquarius',
#  'Pisces',
#  'Cancer',
#  'Capricorn',
#  'Pisces',
#  'Pisces',
#  'Aries',
#  'Aries',
#  'Taurus',
#  'Pisces',
#  'Taurus',
#  'Libra',
#  'Pisces',
#  'Sagittarius',
#  'Capricorn',
#  'Cancer',
#  'Capricorn',
#  'Aquarius',
#  'Aries',
#  'Aquarius',
#  'Pisces',
#  'Aquarius',
#  'Cancer',
#  'Aquarius',
#  'Taurus',
#  'Scorpio',
#  'Pisces',
#  'Cancer',
#  'Cancer',
#  'Taurus',
#  'Aries',
#  'Capricorn',
#  'Taurus',
#  'Taurus',
#  'Scorpio',
#  'Aries',
#  'Sagittarius',
#  'Taurus',
#  'Sagittarius',
#  'Capricorn',
#  'Taurus',
#  'Libra',
#  'Capricorn',
#  'Libra',
#  'Aries',
#  'Sagittarius',
#  'Capricorn',
#  'Scorpio',
#  'Pisces',
#  'Sagittarius',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Aquarius',
#  'Libra',
#  'Taurus',
#  'Pisces',
#  'Leo',
#  'Aquarius',
#  'Capricorn',
#  'Pisces',
#  'Capricorn',
#  'Aquarius',
#  'Leo',
#  'Cancer',
#  'Pisces',
#  'Libra',
#  'Pisces',
#  'Capricorn',
#  'Capricorn',
#  'Taurus',
#  'Pisces',
#  'Scorpio',
#  'Sagittarius',
#  'Libra',
#  'Taurus',
#  'Pisces',
#  'Sagittarius',
#  'Aries',
#  'Capricorn',
#  'Cancer',
#  'Sagittarius',
#  'Pisces',
#  'Leo',
#  'Pisces',
#  'Capricorn',
#  'Aries',
#  'Pisces',
#  'Capricorn',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Pisces',
#  'Capricorn',
#  'Aries',
#  'Aquarius',
#  'Aquarius',
#  'Pisces',
#  'Capricorn',
#  'Taurus',
#  'Aries',
#  'Aries',
#  'Aries',
#  'Taurus',
#  'Pisces',
#  'Sagittarius',
#  'Sagittarius',
#  'Pisces',
#  'Taurus',
#  'Cancer',
#  'Sagittarius',
#  'Pisces',
#  'Sagittarius',
#  'Aries',
#  'Aquarius',
#  'Taurus',
#  'Aquarius',
#  'Virgo',
#  'Pisces',
#  'Aquarius',
#  'Sagittarius',
#  'Taurus',
#  'Aries',
#  'Taurus',
#  'Aries',
#  'Taurus',
#  'Taurus',
#  'Capricorn',
#  'Sagittarius',
#  'Aries',
#  'Aries',
#  'Pisces',
#  'Sagittarius',
#  'Taurus',
#  'Taurus',
#  'Aquarius',
#  'Taurus',
#  'Sagittarius',
#  'Pisces',
#  'Pisces',
#  'Taurus',
#  'Scorpio',
#  'Capricorn',
#  'Aquarius',
#  'Taurus',
#  'Aries',
#  'Aries',
#  'Scorpio',
#  'Sagittarius',
#  'Sagittarius',
#  'Cancer',
#  'Pisces',
#  'Sagittarius',
#  'Virgo',
#  'Sagittarius',
#  'Aquarius',
#  'Capricorn',
#  'Taurus',
#  'Aries',
#  'Leo',
#  'Capricorn',
#  'Taurus',
#  'Aquarius',
#  'Aries',
#  'Taurus',
#  'Aquarius',
#  'Taurus',
#  'Capricorn',
#  'Sagittarius',
#  'Pisces',
#  'Taurus',
#  'Aries',
#  'Capricorn',
#  'Aquarius',
#  'Pisces',
#  'Pisces',
#  'Aries',
#  'Taurus',
#  'Capricorn',
#  'Pisces',
#  'Pisces',
#  'Sagittarius',
#  'Pisces',
#  'Capricorn',
#  'Virgo',
#  'Scorpio',
#  'Sagittarius',
#  'Sagittarius',
#  'Pisces',
#  'Pisces',
#  'Virgo',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Scorpio',
#  'Aries',
#  'Pisces',
#  'Aquarius',
#  'Aries',
#  'Taurus',
#  'Cancer',
#  'Taurus',
#  'Aquarius',
#  'Leo',
#  'Pisces',
#  'Sagittarius',
#  'Pisces',
#  'Pisces',
#  'Pisces',
#  'Scorpio',
#  'Sagittarius',
#  'Aquarius',
#  'Cancer',
#  'Scorpio',
#  'Sagittarius',
#  'Aries',
#  'Sagittarius',
#  'Libra',
#  'Aquarius',
#  'Cancer',
#  'Pisces',
#  'Sagittarius',
#  'Taurus',
#  'Aquarius',
#  'Sagittarius',
#  'Aries',
#  'Libra',
#  'Capricorn',
#  'Pisces',
#  'Aries',
#  'Pisces',
#  'Virgo',
#  'Pisces',
#  'Sagittarius',
#  'Aquarius',
#  'Sagittarius',
#  'Capricorn',
#  'Cancer',
#  'Sagittarius',
#  'Aquarius',
#  'Pisces',
#  'Aquarius',
#  'Capricorn',
#  'Pisces',
#  'Cancer',
#  'Capricorn',
#  'Scorpio',
#  'Virgo',
#  'Libra',
#  'Libra',
#  'Cancer',
#  'Capricorn',
#  'Libra',
#  'Pisces',
#  'Capricorn',
#  'Taurus',
#  'Libra',
#  'Leo',
#  'Aquarius',
#  'Pisces',
#  'Pisces',
#  'Capricorn',
#  'Cancer',
#  'Taurus',
#  'Pisces',
#  'Sagittarius',
#  'Aquarius',
#  'Sagittarius',
#  'Capricorn',
#  'Scorpio',
#  'Aquarius',
#  'Sagittarius',
#  'Scorpio',
#  'Leo',
#  'Aries',
#  'Virgo',
#  'Aries',
#  'Pisces',
#  'Taurus',
#  'Aquarius',
#  'Pisces',
#  'Capricorn',
#  'Sagittarius',
#  'Taurus',
#  'Scorpio',
#  'Leo',
#  'Taurus',
#  'Sagittarius',
#  'Cancer',
#  'Pisces',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Scorpio',
#  'Capricorn',
#  'Taurus',
#  'Taurus',
#  'Pisces',
#  'Libra',
#  'Capricorn',
#  'Taurus',
#  'Taurus',
#  'Scorpio',
#  'Scorpio',
#  'Taurus',
#  'Capricorn',
#  'Sagittarius',
#  'Capricorn',
#  'Taurus',
#  'Aquarius',
#  'Taurus',
#  'Scorpio',
#  'Aquarius',
#  'Aries',
#  'Cancer',
#  'Pisces',
#  'Pisces',
#  'Sagittarius',
#  'Pisces',
#  'Pisces',
#  'Aquarius',
#  'Pisces',
#  'Taurus',
#  'Capricorn',
#  'Capricorn',
#  'Sagittarius',
#  'Aquarius',
#  'Aries',
#  'Aquarius',
#  'Capricorn',
#  'Taurus',
#  'Taurus',
#  'Capricorn',
#  'Leo',
#  'Aquarius',
#  'Scorpio',
#  'Aquarius',
#  'Pisces',
#  'Cancer',
#  'Taurus',
#  'Pisces',
#  'Sagittarius',
#  'Pisces',
#  'Capricorn',
#  'Pisces',
#  'Sagittarius',
#  'Sagittarius',
#  'Taurus',
#  'Leo',
#  'Aries',
#  'Taurus',
#  'Aquarius',
#  'Aries',
#  'Leo',
#  'Pisces',
#  'Capricorn',
#  'Capricorn',
#  'Taurus',
#  'Scorpio',
#  'Sagittarius',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Aquarius',
#  'Scorpio',
#  'Aries',
#  'Scorpio',
#  'Taurus',
#  'Aquarius',
#  'Cancer',
#  'Aries',
#  'Sagittarius',
#  'Pisces',
#  'Virgo',
#  'Aquarius',
#  'Scorpio',
#  'Sagittarius',
#  'Pisces',
#  'Aquarius',
#  'Aries',
#  'Capricorn',
#  'Scorpio',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Aries',
#  'Libra',
#  'Taurus',
#  'Capricorn',
#  'Aquarius',
#  'Capricorn',
#  'Aquarius',
#  'Leo',
#  'Pisces',
#  'Libra',
#  'Aquarius',
#  'Capricorn',
#  'Taurus',
#  'Aries',
#  'Aries',
#  'Aries',
#  'Scorpio',
#  'Taurus',
#  'Aries',
#  'Aquarius',
#  'Virgo',
#  'Aquarius',
#  'Scorpio',
#  'Scorpio',
#  'Scorpio',
#  'Scorpio',
#  'Aquarius',
#  'Libra',
#  'Pisces',
#  'Aries',
#  'Aquarius',
#  'Taurus',
#  'Capricorn',
#  'Aries',
#  'Sagittarius',
#  'Aries',
#  'Pisces',
#  'Pisces',
#  'Aquarius',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Capricorn',
#  'Pisces',
#  'Pisces',
#  'Capricorn',
#  'Capricorn',
#  'Pisces',
#  'Libra',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Aquarius',
#  'Taurus',
#  'Taurus',
#  'Aquarius',
#  'Cancer',
#  'Pisces',
#  'Taurus',
#  'Sagittarius',
#  'Cancer',
#  'Pisces',
#  'Leo',
#  'Libra',
#  'Scorpio',
#  'Pisces',
#  'Aries',
#  'Capricorn',
#  'Pisces',
#  'Aries',
#  'Sagittarius',
#  'Cancer',
#  'Pisces',
#  'Sagittarius',
#  'Capricorn',
#  'Scorpio',
#  'Capricorn',
#  'Cancer',
#  'Aries',
#  'Sagittarius',
#  'Cancer',
#  'Scorpio',
#  'Pisces',
#  'Libra',
#  'Taurus',
#  'Leo',
#  'Pisces',
#  'Pisces',
#  'Pisces',
#  'Pisces',
#  'Taurus',
#  'Aries',
#  'Taurus',
#  'Cancer',
#  'Taurus',
#  'Sagittarius',
#  'Libra',
#  'Aquarius',
#  'Taurus',
#  'Capricorn',
#  'Taurus',
#  'Sagittarius',
#  'Leo',
#  'Aries',
#  'Taurus',
#  'Capricorn',
#  'Scorpio',
#  'Scorpio',
#  'Taurus',
#  'Sagittarius',
#  'Pisces',
#  'Aquarius',
#  'Sagittarius',
#  'Pisces',
#  'Pisces',
#  'Sagittarius',
#  'Aries',
#  'Aries',
#  'Aries',
#  'Scorpio',
#  'Virgo',
#  'Pisces',
#  'Taurus',
#  'Pisces',
#  'Aquarius',
#  'Aquarius',
#  'Capricorn',
#  'Capricorn',
#  'Scorpio',
#  'Aries',
#  'Leo',
#  'Scorpio',
#  'Capricorn',
#  'Scorpio',
#  'Scorpio',
#  'Taurus',
#  'Aries',
#  'Aquarius',
#  'Cancer',
#  'Pisces',
#  'Taurus',
#  'Cancer',
#  'Sagittarius',
#  'Aquarius',
#  'Scorpio',
#  'Taurus',
#  'Cancer',
#  'Scorpio',
#  'Capricorn',
#  'Aquarius',
#  'Taurus',
#  'Aries',
#  'Scorpio',
#  'Aquarius',
#  'Aries',
#  'Capricorn',
#  'Capricorn',
#  'Scorpio',
#  'Pisces',
#  'Capricorn',
#  'Aries',
#  'Scorpio',
#  'Pisces',
#  'Aquarius',
#  'Capricorn',
#  'Capricorn',
#  'Sagittarius',
#  'Cancer',
#  'Sagittarius',
#  'Capricorn',
#  'Leo',
#  'Pisces',
#  'Taurus',
#  'Aquarius',
#  'Cancer',
#  'Aquarius',
#  'Libra',
#  'Aquarius',
#  'Leo',
#  'Taurus',
#  'Aquarius',
#  'Cancer',
#  'Capricorn',
#  'Aquarius',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Virgo',
#  'Aries',
#  'Taurus',
#  'Capricorn',
#  'Aquarius',
#  'Aries',
#  'Taurus',
#  'Taurus',
#  'Pisces',
#  'Capricorn',
#  'Sagittarius',
#  'Cancer',
#  'Aquarius',
#  'Libra',
#  'Pisces',
#  'Capricorn',
#  'Scorpio',
#  'Taurus',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Libra',
#  'Libra',
#  'Taurus',
#  'Capricorn',
#  'Taurus',
#  'Capricorn',
#  'Aquarius',
#  'Taurus',
#  'Sagittarius',
#  'Aquarius',
#  'Capricorn',
#  'Sagittarius',
#  'Cancer',
#  'Capricorn',
#  'Pisces',
#  'Libra',
#  'Aquarius',
#  'Aries',
#  'Aquarius',
#  'Taurus',
#  'Libra',
#  'Cancer',
#  'Aries',
#  'Pisces',
#  'Leo',
#  'Sagittarius',
#  'Scorpio',
#  'Taurus',
#  'Taurus',
#  'Aries',
#  'Scorpio',
#  'Taurus',
#  'Leo',
#  'Taurus',
#  'Aquarius',
#  'Taurus',
#  'Pisces',
#  'Taurus',
#  'Sagittarius',
#  'Aries',
#  'Aquarius',
#  'Taurus',
#  'Sagittarius',
#  'Capricorn',
#  'Taurus',
#  'Sagittarius',
#  'Taurus',
#  'Aquarius',
#  'Capricorn',
#  'Taurus',
#  'Pisces',
#  'Aries',
#  'Pisces',
#  'Sagittarius',
#  'Libra',
#  'Aquarius',
#  'Capricorn',
#  'Pisces',
#  'Cancer',
#  'Aries',
#  'Pisces',
#  'Pisces',
#  'Capricorn',
#  'Scorpio',
#  'Capricorn',
#  'Aquarius',
#  'Virgo',
#  'Aquarius',
#  'Aquarius',
#  'Sagittarius',
#  'Libra',
#  'Capricorn',
#  'Aries',
#  'Aquarius',
#  'Pisces',
#  'Taurus',
#  'Taurus',
#  'Taurus',
#  'Cancer',
#  'Pisces',
#  'Sagittarius',
#  'Cancer',
#  'Taurus',
#  'Cancer',
#  'Capricorn',
#  'Cancer',
#  'Scorpio',
#  'Scorpio',
#  'Aquarius',
#  'Libra',
#  'Leo',
#  'Capricorn',
#  'Taurus',
#  'Scorpio',
#  'Cancer',
#  'Capricorn',
#  'Pisces',
#  'Scorpio',
#  'Aquarius',
#  'Scorpio',
#  'Capricorn',
#  'Taurus',
#  'Libra',
#  'Pisces',
#  'Sagittarius',
#  'Aquarius',
#  'Scorpio',
#  'Scorpio',
#  'Pisces',
#  'Aries',
#  'Sagittarius',
#  'Pisces',
#  'Scorpio',
#  'Taurus',
#  'Pisces',
#  'Taurus',
#  'Capricorn',
#  'Sagittarius',
#  'Pisces',
#  'Capricorn',
#  'Aquarius',
#  'Aries',
#  'Pisces',
#  'Aries',
#  'Cancer',
#  'Pisces',
#  'Aries',
#  'Aquarius',
#  'Pisces',
#  'Scorpio',
#  'Taurus',
#  'Aquarius',
#  'Scorpio',
#  'Taurus',
#  'Pisces',
#  'Pisces',
#  'Scorpio',
#  'Pisces',
#  'Libra',
#  'Capricorn',
#  'Libra',
#  'Scorpio',
#  'Taurus',
#  'Pisces',
#  'Cancer',
#  'Taurus',
#  'Taurus',
#  'Aries',
#  'Capricorn',
#  'Sagittarius',
#  'Aquarius',
#  'Scorpio',
#  'Aquarius',
#  'Capricorn',
#  'Aquarius',
#  'Libra',
#  'Capricorn',
#  'Taurus',
#  'Cancer',
#  'Taurus',
#  'Libra',
#  'Taurus',
#  'Libra',
#  'Pisces',
#  'Cancer',
#  'Pisces',
#  'Capricorn',
#  'Virgo',
#  'Pisces',
#  'Capricorn',
#  'Taurus',
#  'Aquarius',
#  'Libra',
#  'Leo',
#  'Cancer',
#  'Capricorn',
#  'Cancer',
#  'Aquarius',
#  'Cancer',
#  'Sagittarius',
#  'Scorpio',
#  'Pisces',
#  'Pisces',
#  'Taurus',
#  'Sagittarius',
#  'Pisces',
#  'Scorpio',
#  'Pisces',
#  'Cancer',
#  'Sagittarius',
#  'Capricorn',
#  'Taurus',
#  'Aries',
#  'Libra',
#  'Pisces',
#  'Leo',
#  'Aquarius',
#  'Taurus',
#  'Leo',
#  'Taurus',
#  'Capricorn',
#  'Capricorn',
#  'Capricorn',
#  'Taurus',
#  'Capricorn',
#  'Taurus',
#  'Libra',
#  'Leo',
#  'Leo',
#  'Aries',
#  'Capricorn',
#  'Capricorn',
#  'Capricorn',
#  'Capricorn',
#  'Taurus',
#  'Taurus',
#  'Scorpio',
#  'Pisces',
#  'Taurus',
#  'Scorpio',
#  'Libra',
#  'Scorpio',
#  'Taurus',
#  'Leo',
#  'Taurus',
#  'Pisces',
#  'Aquarius',
#  'Libra',
#  'Sagittarius',
#  'Taurus',
#  'Scorpio',
#  'Cancer',
#  'Pisces',
#  'Capricorn',
#  'Capricorn',
#  'Taurus',
#  'Scorpio',
#  'Pisces',
#  'Pisces',
#  'Capricorn',
#  'Taurus',
#  'Capricorn',
#  'Sagittarius',
#  'Scorpio',
#  'Libra',
#  'Sagittarius',
#  'Pisces',
#  'Aquarius',
#  'Sagittarius',
#  'Pisces',
#  'Aries',
#  'Pisces',
#  'Aries',
#  'Taurus',
#  'Libra',
#  'Taurus',
#  'Capricorn',
#  'Aries',
#  'Cancer',
#  'Aries',
#  'Capricorn',
#  'Capricorn',
#  'Virgo',
#  'Taurus',
#  'Aquarius',
#  'Leo',
#  'Aquarius',
#  'Scorpio',
#  'Sagittarius',
#  'Aries',
#  'Capricorn',
#  'Leo',
#  'Taurus',
#  'Libra',
#  'Virgo',
#  'Scorpio',
#  'Pisces',
#  'Leo',
#  'Aquarius',
#  'Sagittarius',
#  'Pisces',
#  'Leo',
#  'Taurus',
#  'Pisces',
#  'Aries',
#  'Pisces',
#  'Sagittarius',
#  'Virgo',
#  'Pisces',
#  'Aries',
#  'Scorpio',
#  'Aries',
#  'Sagittarius',
#  'Taurus',
#  'Capricorn',
#  'Pisces',
#  'Pisces',
#  'Scorpio',
#  'Capricorn',
#  'Aquarius',
#  'Scorpio',
#  'Sagittarius',
#  'Taurus',
#  'Leo',
#  'Taurus',
#  'Capricorn',
#  'Scorpio',
#  'Scorpio',
#  'Pisces',
#  'Sagittarius',
#  'Libra',
#  'Cancer',
#  'Aries',
#  'Libra',
#  'Aries',
#  'Cancer',
#  'Scorpio',
#  'Pisces',
#  'Taurus',
#  'Capricorn',
#  'Scorpio',
#  'Aquarius',
#  'Taurus',
#  'Aries',
#  'Libra',
#  'Aquarius',
#  'Taurus',
#  'Aquarius',
#  'Cancer',
#  'Taurus',
#  'Aries',
#  'Libra',
#  'Virgo',
#  'Capricorn',
#  'Aries',
#  'Taurus',
#  'Aries',
#  'Taurus',
#  'Capricorn',
#  'Libra',
#  'Cancer',
#  'Sagittarius',
#  'Pisces',
#  'Aquarius',
#  'Capricorn',
#  'Pisces',
#  'Aries',
#  'Aries',
#  'Scorpio',
#  'Leo',
#  'Pisces',
#  'Scorpio',
#  'Sagittarius',
#  'Pisces',
#  'Scorpio',
#  'Pisces',
#  'Taurus',
#  'Cancer',
#  'Cancer',
#  'Sagittarius',
#  'Taurus',
#  'Capricorn',
#  'Taurus',
#  'Aries',
#  'Pisces',
#  'Taurus',
#  'Virgo',
#  'Sagittarius',
#  'Sagittarius',
#  'Aries',
#  'Pisces',
#  'Pisces',
#  'Aquarius',
#  'Cancer',
#  'Sagittarius',
#  'Leo',
#  'Sagittarius',
#  'Pisces',
#  'Cancer',
#  'Capricorn',
#  'Cancer',
#  'Aquarius',
#  'Cancer',
#  'Pisces',
#  'Aquarius',
#  'Aquarius',
#  'Scorpio',
#  'Taurus',
#  'Aries',
#  'Cancer',
#  'Aries',
#  'Capricorn',
#  'Capricorn',
#  'Libra']

# %% [markdown]
# Now we count all occurrences of each zodiac sign in the data:

# %%
# Counting with for loop
def count_dict(data):
    counts = {}
    for item in data:
        if item in counts:
            counts[item] += 1
        else:
            counts[item] = 1
    return counts
zodiac_counts = count_dict(data_big)
print(zodiac_counts)

# Counting with Counter
zodiac_counts = Counter(data_big)
print(zodiac_counts)
# Out:
# {'Taurus': 173, 'Pisces': 161, 'Aries': 95, 'Capricorn': 123, 'Libra': 50, 'Sagittarius': 95, 'Aquarius': 107, 'Cancer': 62, 'Scorpio': 82, 'Leo': 34, 'Virgo': 18}
# Counter({'Taurus': 173, 'Pisces': 161, 'Capricorn': 123, 'Aquarius': 107, 'Aries': 95, 'Sagittarius': 95, 'Scorpio': 82, 'Cancer': 62, 'Libra': 50, 'Leo': 34, 'Virgo': 18})

# %% [markdown]
# Both codes give the same result. However the code that uses Counter is clean, simple, easy to understand and the result is even sorted. How about execution time?

# %%
# %timeit -r10 -n10000 count_dict(data_big)

# %timeit -r10 -n10000 Counter(data_big)
# Out:
# 73.6 μs ± 590 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 31.9 μs ± 471 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ## Generating all possible combinations in loop vs itertools.combinations

# %%
help(combinations)
# Out:
# Help on class combinations in module itertools:
#
# class combinations(builtins.object)
#  |  combinations(iterable, r)
#  |
#  |  Return successive r-length combinations of elements in the iterable.
#  |
#  |  combinations(range(4), 3) --> (0,1,2), (0,1,3), (0,2,3), (1,2,3)
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __setstate__(...)
#  |      Set state information for unpickling.
#  |
#  |  __sizeof__(...)
#  |      Returns size in memory, in bytes.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
# Combinations with for loops
def combinations_loop(data):
    combinations = []
    for i in data:
        for j in data:
            if i == j:
                continue
            if ((i, j) not in combinations) and ((j, i) not in combinations):
                combinations.append((i, j))
    return combinations
combos_loop = combinations_loop(zodiacs)
print(combos_loop)
print(len(combos_loop))

# Combinations with combinations
combos_itertools = [*combinations(zodiacs, 2)]
print(combos_itertools)
print(len(combos_itertools))

print(combos_loop == combos_itertools)
# Out:
# [('Aries', 'Taurus'), ('Aries', 'Gemini'), ('Aries', 'Cancer'), ('Aries', 'Leo'), ('Aries', 'Virgo'), ('Aries', 'Libra'), ('Aries', 'Scorpio'), ('Aries', 'Sagittarius'), ('Aries', 'Capricorn'), ('Aries', 'Aquarius'), ('Aries', 'Pisces'), ('Taurus', 'Gemini'), ('Taurus', 'Cancer'), ('Taurus', 'Leo'), ('Taurus', 'Virgo'), ('Taurus', 'Libra'), ('Taurus', 'Scorpio'), ('Taurus', 'Sagittarius'), ('Taurus', 'Capricorn'), ('Taurus', 'Aquarius'), ('Taurus', 'Pisces'), ('Gemini', 'Cancer'), ('Gemini', 'Leo'), ('Gemini', 'Virgo'), ('Gemini', 'Libra'), ('Gemini', 'Scorpio'), ('Gemini', 'Sagittarius'), ('Gemini', 'Capricorn'), ('Gemini', 'Aquarius'), ('Gemini', 'Pisces'), ('Cancer', 'Leo'), ('Cancer', 'Virgo'), ('Cancer', 'Libra'), ('Cancer', 'Scorpio'), ('Cancer', 'Sagittarius'), ('Cancer', 'Capricorn'), ('Cancer', 'Aquarius'), ('Cancer', 'Pisces'), ('Leo', 'Virgo'), ('Leo', 'Libra'), ('Leo', 'Scorpio'), ('Leo', 'Sagittarius'), ('Leo', 'Capricorn'), ('Leo', 'Aquarius'), ('Leo', 'Pisces'), ('Virgo', 'Libra'), ('Virgo', 'Scorpio'), ('Virgo', 'Sagittarius'), ('Virgo', 'Capricorn'), ('Virgo', 'Aquarius'), ('Virgo', 'Pisces'), ('Libra', 'Scorpio'), ('Libra', 'Sagittarius'), ('Libra', 'Capricorn'), ('Libra', 'Aquarius'), ('Libra', 'Pisces'), ('Scorpio', 'Sagittarius'), ('Scorpio', 'Capricorn'), ('Scorpio', 'Aquarius'), ('Scorpio', 'Pisces'), ('Sagittarius', 'Capricorn'), ('Sagittarius', 'Aquarius'), ('Sagittarius', 'Pisces'), ('Capricorn', 'Aquarius'), ('Capricorn', 'Pisces'), ('Aquarius', 'Pisces')]
# 66
# [('Aries', 'Taurus'), ('Aries', 'Gemini'), ('Aries', 'Cancer'), ('Aries', 'Leo'), ('Aries', 'Virgo'), ('Aries', 'Libra'), ('Aries', 'Scorpio'), ('Aries', 'Sagittarius'), ('Aries', 'Capricorn'), ('Aries', 'Aquarius'), ('Aries', 'Pisces'), ('Taurus', 'Gemini'), ('Taurus', 'Cancer'), ('Taurus', 'Leo'), ('Taurus', 'Virgo'), ('Taurus', 'Libra'), ('Taurus', 'Scorpio'), ('Taurus', 'Sagittarius'), ('Taurus', 'Capricorn'), ('Taurus', 'Aquarius'), ('Taurus', 'Pisces'), ('Gemini', 'Cancer'), ('Gemini', 'Leo'), ('Gemini', 'Virgo'), ('Gemini', 'Libra'), ('Gemini', 'Scorpio'), ('Gemini', 'Sagittarius'), ('Gemini', 'Capricorn'), ('Gemini', 'Aquarius'), ('Gemini', 'Pisces'), ('Cancer', 'Leo'), ('Cancer', 'Virgo'), ('Cancer', 'Libra'), ('Cancer', 'Scorpio'), ('Cancer', 'Sagittarius'), ('Cancer', 'Capricorn'), ('Cancer', 'Aquarius'), ('Cancer', 'Pisces'), ('Leo', 'Virgo'), ('Leo', 'Libra'), ('Leo', 'Scorpio'), ('Leo', 'Sagittarius'), ('Leo', 'Capricorn'), ('Leo', 'Aquarius'), ('Leo', 'Pisces'), ('Virgo', 'Libra'), ('Virgo', 'Scorpio'), ('Virgo', 'Sagittarius'), ('Virgo', 'Capricorn'), ('Virgo', 'Aquarius'), ('Virgo', 'Pisces'), ('Libra', 'Scorpio'), ('Libra', 'Sagittarius'), ('Libra', 'Capricorn'), ('Libra', 'Aquarius'), ('Libra', 'Pisces'), ('Scorpio', 'Sagittarius'), ('Scorpio', 'Capricorn'), ('Scorpio', 'Aquarius'), ('Scorpio', 'Pisces'), ('Sagittarius', 'Capricorn'), ('Sagittarius', 'Aquarius'), ('Sagittarius', 'Pisces'), ('Capricorn', 'Aquarius'), ('Capricorn', 'Pisces'), ('Aquarius', 'Pisces')]
# 66
# True

# %%
# %timeit -r10 -n10000 combinations_loop(zodiacs)

# %timeit -r10 -n10000 [*combinations(zodiacs, 2)]
# Out:
# 149 μs ± 2.29 μs per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 1.36 μs ± 30.6 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# Difference in execution time is outstanding.

# %% [markdown]
# ## Comparing two list of objects using set theory
# Examples of set theory operations

# %% [markdown]
# Prepare some example data:

# %%
data1 = np.random.choice(zodiacs, replace=False, size=8).tolist()
data2 = np.random.choice(zodiacs, replace=False, size=8).tolist()

print(data1)
print(data2)
# Out:
# ['Cancer', 'Capricorn', 'Virgo', 'Scorpio', 'Pisces', 'Libra', 'Sagittarius', 'Gemini']
# ['Scorpio', 'Gemini', 'Leo', 'Cancer', 'Taurus', 'Virgo', 'Capricorn', 'Pisces']

# %% [markdown]
# ### Find common elements
# Find intersection of two sets - elements that are present in both sets

# %%
# For loop solution
def find_common_elements(data1, data2):
    common = []
    for i in data1:
        for j in data2:
            if i == j:
                common.append(i)
    return common
commons_loop = find_common_elements(data1, data2)
print(commons_loop)

# Set solution with & operator
commons_operator = set(data1) & set(data2)
print(commons_operator)

# Set solution with intersection
commons_method = set(data1).intersection(data2)
print(commons_method)

# Check if they have the same elements
print(set(commons_loop) == commons_operator == commons_method)
# Out:
# ['Cancer', 'Capricorn', 'Virgo', 'Scorpio', 'Pisces', 'Gemini']
# {'Virgo', 'Pisces', 'Scorpio', 'Cancer', 'Gemini', 'Capricorn'}
# {'Pisces', 'Cancer', 'Scorpio', 'Virgo', 'Gemini', 'Capricorn'}
# True

# %%
# %timeit -r10 -n10000 find_common_elements(data1, data2)

# %timeit -r10 -n10000 set(data1) & set(data2)

# %timeit -r10 -n10000 set(data1).intersection(data2)
# Out:
# 1.67 μs ± 53.1 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 539 ns ± 17.2 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 435 ns ± 5.57 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ### Find differences
# Find difference of two sets - elements that are present in first set but not in the second

# %%
# For loop
def find_difference(data1, data2):
    difference = []
    for i in data1:
        if i not in data2:
            difference.append(i)
    return difference
difference_loop = find_difference(data1, data2)
print(difference_loop)

# Set solution with - operator
difference_operator = set(data1) - set(data2)
print(difference_operator)

# Set solution with difference
difference_method = set(data1).difference(data2)
print(difference_method)

# Check if they have the same elements
print(set(difference_loop) == difference_operator == difference_method)
# Out:
# ['Libra', 'Sagittarius']
# {'Sagittarius', 'Libra'}
# {'Sagittarius', 'Libra'}
# True

# %%
# %timeit -r10 -n10000 find_difference(data1, data2)

# %timeit -r10 -n10000 set(data1) - set(data2)

# %timeit -r10 -n10000 set(data1).difference(data2)
# Out:
# 644 ns ± 23.7 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 451 ns ± 14 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 424 ns ± 8.73 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ### Find symmetric difference
# Find symmetric difference of two sets - elements that are present only in one of the sets and not in the other

# %%
# For loop
def find_symmetric_difference(data1, data2):
    symmetric_difference = []
    for i in data1:
        if i not in data2:
            symmetric_difference.append(i)
    for i in data2:
        if i not in data1:
            symmetric_difference.append(i)
    return symmetric_difference
symmetric_difference_loop = find_symmetric_difference(data1, data2)
print(symmetric_difference_loop)

# Set solution with ^ operator
symmetric_difference_operator = set(data1) ^ set(data2)
print(symmetric_difference_operator)

# Set solution with symmetric_difference
symmetric_difference_method = set(data1).symmetric_difference(data2)
print(symmetric_difference_method)

# Check if they have the same elements
print(set(symmetric_difference_loop) == symmetric_difference_operator == symmetric_difference_method)
# Out:
# ['Libra', 'Sagittarius', 'Leo', 'Taurus']
# {'Sagittarius', 'Leo', 'Libra', 'Taurus'}
# {'Sagittarius', 'Leo', 'Libra', 'Taurus'}
# True

# %%
# %timeit -r10 -n10000 find_symmetric_difference(data1, data2)

# %timeit -r10 -n10000 set(data1) ^ set(data2)

# %timeit -r10 -n10000 set(data1).symmetric_difference(data2)
# Out:
# 1.22 μs ± 66.7 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 570 ns ± 14.1 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 441 ns ± 5.37 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ### Find union
# Find union of two sets - elements that are present in both sets

# %%
# For loop
def find_union(data1, data2):
    union = []
    for i in data1:
        if i not in union:
            union.append(i)
    for i in data2:
        if i not in union:
            union.append(i)
    return union
union_loop = find_union(data1, data2)
print(union_loop)

# Set solution with | operator
union_operator = set(data1) | set(data2)
print(union_operator)

# Set solution with union
union_method = set(data1).union(data2)
print(union_method)

# Check if they have the same elements
print(set(union_loop) == union_operator == union_method)
# Out:
# ['Cancer', 'Capricorn', 'Virgo', 'Scorpio', 'Pisces', 'Libra', 'Sagittarius', 'Gemini', 'Leo', 'Taurus']
# {'Sagittarius', 'Pisces', 'Cancer', 'Gemini', 'Leo', 'Scorpio', 'Libra', 'Taurus', 'Virgo', 'Capricorn'}
# {'Sagittarius', 'Pisces', 'Cancer', 'Gemini', 'Leo', 'Scorpio', 'Libra', 'Taurus', 'Virgo', 'Capricorn'}
# True

# %%
# %timeit -r10 -n10000 find_union(data1, data2)

# %timeit -r10 -n10000 set(data1) | set(data2)

# %timeit -r10 -n10000 set(data1).union(data2)
# Out:
# 1.14 μs ± 33.9 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 520 ns ± 17.6 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 387 ns ± 6.83 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ### Find uniques
# Find unique elements

# %%
# For loop
def find_uniques(data):
    uniques = []
    for i in data:
        if i not in uniques:
            uniques.append(i)
    return uniques
uniques_loop = find_uniques(data_big)
print(uniques_loop)

# Set solution
uniques_operator = set(data_big)
print(uniques_operator)

# Check if they have the same elements
print(set(uniques_loop) == uniques_operator)
# Out:
# ['Taurus', 'Pisces', 'Aries', 'Capricorn', 'Libra', 'Sagittarius', 'Aquarius', 'Cancer', 'Scorpio', 'Leo', 'Virgo']
# {'Virgo', 'Sagittarius', 'Pisces', 'Aries', 'Aquarius', 'Leo', 'Libra', 'Taurus', 'Scorpio', 'Cancer', 'Capricorn'}
# True

# %%
# %timeit -r10 -n10000 find_uniques(data_big)

# %timeit -r10 -n10000 set(data_big)
# Out:
# 62 μs ± 636 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 11.5 μs ± 551 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ### Membership testing in list, tuple and set - speed comparison

# %%
data_list = list(zodiacs)
data_tuple = tuple(zodiacs)
data_set = set(zodiacs)

# %%
# %timeit -r10 -n10000 "Leo" in data_list

# %timeit -r10 -n10000 "Leo" in data_tuple

# %timeit -r10 -n10000 "Leo" in data_set
# Out:
# 46.5 ns ± 1.3 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 44.5 ns ± 0.911 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)
# 19.1 ns ± 0.385 ns per loop (mean ± std. dev. of 10 runs, 10,000 loops each)

# %% [markdown]
# ## Eliminating loops
# Replace loops with list comprehensions, maps and numpy

# %% [markdown]
# ### Sum elements in rows

# %%
big_array_2d = [[i for i in range(500)] for j in range(500)]

# For loop solution
def row_totals(numbers_2d):
    totals = []
    for row in numbers_2d:
        totals.append(sum(row))
    return totals
row_totals_loop = row_totals(big_array_2d)
print(row_totals_loop)

# List comprehension solution
row_totals_list_comprehension = [sum(row) for row in big_array_2d]
print(row_totals_list_comprehension)

# Map solution
row_totals_map = [*map(sum, big_array_2d)]
print(row_totals_map)

# Numpy solution
np_numbers_2d = np.array(big_array_2d)
row_totals_numpy = np_numbers_2d.sum(axis=1).tolist()
print(row_totals_numpy)

# Check if they have the same elements
print(row_totals_loop == row_totals_list_comprehension == row_totals_map == row_totals_numpy)
# Out:
# [124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750]
# [124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750]
# [124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750]
# [124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750, 124750]
# True

# %%
# %timeit -r10 -n1000 row_totals(big_array_2d)

# %timeit -r10 -n1000 [sum(row) for row in big_array_2d]

# %timeit -r10 -n1000 [*map(sum, big_array_2d)]

# %timeit -r10 -n1000 np_numbers_2d.sum(axis=1)
# Out:
# 1.33 ms ± 22.2 μs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)
# 1.33 ms ± 18.1 μs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)
# 1.32 ms ± 29.7 μs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)
# 67.8 μs ± 3.33 μs per loop (mean ± std. dev. of 10 runs, 1,000 loops each)

# %% [markdown]
# ### Sum elements in columns

# %%
# For loop solution
def column_totals(numbers_2d):
    totals = []
    for i in range(len(numbers_2d[0])):
        total = 0
        for row in numbers_2d:
            total += row[i]
        totals.append(total)
    return totals
column_totals_loop = column_totals(big_array_2d)
print(column_totals_loop)

# List comprehension solution
column_totals_list_comprehension = [sum(row[i] for row in big_array_2d) for i in range(len(big_array_2d[0]))]
print(column_totals_list_comprehension)

# Map solution
column_totals_map = [*map(sum, zip(*big_array_2d))]
print(column_totals_map)

# Numpy solution
np_numbers_2d = np.array(big_array_2d)
column_totals_numpy = np_numbers_2d.sum(axis=0).tolist()
print(column_totals_numpy)

# Check if they have the same elements
print(column_totals_loop == column_totals_list_comprehension == column_totals_map == column_totals_numpy)
# Out:
# [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000, 10500, 11000, 11500, 12000, 12500, 13000, 13500, 14000, 14500, 15000, 15500, 16000, 16500, 17000, 17500, 18000, 18500, 19000, 19500, 20000, 20500, 21000, 21500, 22000, 22500, 23000, 23500, 24000, 24500, 25000, 25500, 26000, 26500, 27000, 27500, 28000, 28500, 29000, 29500, 30000, 30500, 31000, 31500, 32000, 32500, 33000, 33500, 34000, 34500, 35000, 35500, 36000, 36500, 37000, 37500, 38000, 38500, 39000, 39500
 85500, 86000, 86500, 87000, 87500, 88000, 88500, 89000, 89500, 90000, 90500, 91000, 91500, 92000, 92500, 93000, 93500, 94000, 94500, 95000, 95500, 96000, 96500, 97000, 97500, 98000, 98500, 99000, 99500, 100000, 100500, 101000, 101500, 102000, 102500, 103000, 103500, 104000, 104500, 105000, 105500, 106000, 106500, 107000, 107500, 108000, 108500, 109000, 109500, 110000, 110500, 111000, 111500, 112000, 112500, 113000, 113500, 114000, 114500, 115000, 115500, 116000, 116500, 117000, 117500, 118000, 118500, 119000, 119500, 120000, 120500, 121000, 121500, 122000, 122500, 123000, 123500, 124000, 124500, 125000, 125500, 126000, 126500, 127000, 127500, 128000, 128500, 129000, 129500, 130000, 130500, 131000, 131500, 132000, 132500, 133000, 133500, 134000, 134500, 135000, 135500, 136000, 136500, 137000, 137500, 138000, 138500, 139000, 139500, 140000, 140500, 141000, 141500, 142000, 142500, 143000, 143500, 144000, 144500, 145000, 145500, 146000, 146500, 147000, 147500, 148000, 148500, 149000, 149500, 150000, 150500, 151000, 151500, 152000, 152500, 153000, 153500, 154000, 154500, 155000, 155500, 156000, 156500, 157000, 157500, 158000, 158500, 159000, 159500, 160000, 160500, 161000, 161500, 162000, 162500, 163000, 163500, 164000, 164500, 165000, 165500, 166000, 166500, 167000, 167500, 168000, 168500, 169000, 169500, 170000, 170500, 171000, 171500, 172000, 172500, 173000, 173500, 174000, 174500, 175000, 175500, 176000, 176500, 177000, 177500, 178000, 178500, 179000, 179500, 180000, 180500, 181000, 181500, 182000, 182500, 183000, 183500, 184000, 184500, 185000, 185500, 186000, 186500, 187000, 187500, 188000, 188500, 189000, 189500, 190000, 190500, 191000, 191500, 192000, 192500, 193000, 193500, 194000, 194500, 195000, 195500, 196000, 196500, 197000, 197500, 198000, 198500, 199000, 199500, 200000, 200500, 201000, 201500, 202000, 202500, 203000, 203500, 204000, 204500, 205000, 205500, 206000, 206500, 207000, 207500, 208000, 208500, 209000, 209500, 210000, 210500, 211000, 211500, 212000, 212500, 213000, 213500, 214000, 214500, 215000, 215500, 216000, 216500, 217000, 217500, 218000, 218500, 219000, 219500, 220000, 220500, 221000, 221500, 222000, 222500, 223000, 223500, 224000, 224500, 225000, 225500, 226000, 226500, 227000, 227500, 228000, 228500, 229000, 229500, 230000, 230500, 231000, 231500, 232000, 232500, 233000, 233500, 234000, 234500, 235000, 235500, 236000, 236500, 237000, 237500, 238000, 238500, 239000, 239500, 240000, 240500, 241000, 241500, 242000, 242500, 243000, 243500, 244000, 244500, 245000, 245500, 246000, 246500, 247000, 247500, 248000, 248500, 249000, 249500]
# True

# %%
# %timeit -r10 -n100 column_totals(big_array_2d)

# %timeit -r10 -n100 [sum(row[i] for row in big_array_2d) for i in range(len(big_array_2d[0]))]

# %timeit -r10 -n100 [*map(sum, zip(*big_array_2d))]

# %timeit -r10 -n100 np_numbers_2d.sum(axis=0)
# Out:
# 12.1 ms ± 169 μs per loop (mean ± std. dev. of 10 runs, 100 loops each)
# 14.9 ms ± 207 μs per loop (mean ± std. dev. of 10 runs, 100 loops each)
# 3.21 ms ± 454 μs per loop (mean ± std. dev. of 10 runs, 100 loops each)
# 122 μs ± 6.27 μs per loop (mean ± std. dev. of 10 runs, 100 loops each)
